# %%
# !ls
# Out:
# ETL-mRNA_vst_normalized.txt  .ipynb
# ETL-mutmatrix.txt.ipynb
# Export_fromR.R
# GSETS.RData
# GSETS_RES.RData
# GSETS_RES_split_object
# GSET_split_object
# cna_matrix.txt
# mRNA_vst_normalized.rar
# mRNA_vst_normalized.txt
# mRNA_vst_normalized_genesubset.rar
# mRNA_vst_normalized_genesubset.txt
# mRNA_vst_normalized_transposed.txt
# mutmatrix.txt
# sample_pca_and_annotations.xlsx
# sample_pca_annotations_sheet_gene2ptime_correlations.txt
# sample_pca_annotations_sheet_gene_annotations.txt
# sample_pca_annotations_sheet_pca_and_pseudotime.txt
# sample_pca_annotations_sheet_sample_annotations.txt

# %%
import pandas as pd

# %%
df = pd.read_csv("mutmatrix.txt",sep="\t",header=0,index_col=0)

# %%
df.head()
# Out:
#           111208_UNC10-SN254_0313_BD087RACXX_ACTTGA_L001  \
# HIVEP3                                                 0
# PCDHA4                                                 0
# PPP3CC                                                 0
# PCDHA3                                                 0
# KIAA0907                                               0
#
#           111212_UNC15-SN850_0155_AD087AACXX_ACTTGA_L002  \
# HIVEP3                                                 0
# PCDHA4                                                 0
# PPP3CC                                                 0
# PCDHA3                                                 0
# KIAA0907                                               0
#
#           111212_UNC15-SN850_0155_AD087AACXX_ACTTGA_L008  \
# HIVEP3                                                 0
# PCDHA4                                                 0
# PPP3CC                                                 0
# ...

# %%
df2 = df.T

# %%
df2.tail()
# Out:
#             HIVEP3  PCDHA4  PPP3CC  PCDHA3  KIAA0907  PARG  CAMKMT  RDH10  \
# SRR3146950       0       0       0       0         0     0       0      0
# SRR3146974       0       0       0       0         0     0       0      0
# SRR3146977       0       0       0       0         0     0       0      0
# SRR3146980       0       0       0       0         0     0       0      0
# SRR3146981       0       0       0       0         0     0       0      0
#
#             MYOM1  FBXO46  ...  CCR8  POLR3G  OR14I1  C14orf182  NEXN  SYT5  \
# SRR3146950      0       0  ...     0       0       0          0     0     0
# SRR3146974      0       0  ...     0       0       0          0     0     0
# SRR3146977      0       0  ...     0       0       0          0     0     0
# SRR3146980      0       0  ...     0       0       0          0     0     0
# SRR3146981      0       0  ...     0       0       0          0     0     0
#
#             MAT2B  TMEM14B  ACBD4  ISM1
# ...

# %%
df2.isna()
# Out:
#                                                 HIVEP3  PCDHA4  PPP3CC  \
# 111208_UNC10-SN254_0313_BD087RACXX_ACTTGA_L001   False   False   False
# 111212_UNC15-SN850_0155_AD087AACXX_ACTTGA_L002   False   False   False
# 111212_UNC15-SN850_0155_AD087AACXX_ACTTGA_L008   False   False   False
# 111212_UNC15-SN850_0156_BD0KGCACXX_ACTTGA_L002   False   False   False
# 111219_UNC11-SN627_0175_BC0CKKACXX_ACTTGA_L002   False   False   False
# ...                                                ...     ...     ...
# SRR3146950                                       False   False   False
# SRR3146974                                       False   False   False
# SRR3146977                                       False   False   False
# SRR3146980                                       False   False   False
# SRR3146981                                       False   False   False
#
#                                                 PCDHA3  KIAA0907   PARG  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678 entries, 111208_UNC10-SN254_0313_BD087RACXX_ACTTGA_L001 to SRR3146981
# Columns: 12710 entries, HIVEP3 to ISM1
# dtypes: int64(12710)
# memory usage: 65.8+ MB

# %%
df2.to_csv("mutmatrix_transposed.txt",index=True,header=True,sep="\t")

# %%
df2.shape
# Out:
# (678, 12710)

# %%
df2.min()
# Out:
# HIVEP3      0
# PCDHA4      0
# PPP3CC      0
# PCDHA3      0
# KIAA0907    0
#            ..
# SYT5        0
# MAT2B       0
# TMEM14B     0
# ACBD4       0
# ISM1        0
# Length: 12710, dtype: int64
