# %%
# !ls
# Out:
# ETL-mRNA_vst_normalized.txt  .ipynb
# ETL-mutmatrix.txt.ipynb
# Export_fromR.R
# GSETS.RData
# GSETS_RES.RData
# GSETS_RES_split_object
# GSET_split_object
# Untitled.ipynb
# cna_matrix.txt
# mRNA_vst_normalized.rar
# mRNA_vst_normalized.txt
# mRNA_vst_normalized_genesubset.rar
# mRNA_vst_normalized_genesubset.txt
# mRNA_vst_normalized_transposed.txt
# mutmatrix.txt
# mutmatrix_transposed.txt
# sample_pca_and_annotations.xlsx
# sample_pca_annotations_sheet_gene2ptime_correlations.txt
# sample_pca_annotations_sheet_gene_annotations.txt
# sample_pca_annotations_sheet_pca_and_pseudotime.txt
# sample_pca_annotations_sheet_sample_annotations.txt

# %%
import pandas as pd

# %%
df = pd.read_csv("cna_matrix.txt",sep="\t",header=0,index_col=0)

# %%
df.head()
# Out:
#        SRR3018011  SRR3018194  SRR3018197  SRR3018199  SRR3018014  SRR3018016  \
# AR            2.0         1.0         2.0         2.0         2.0         0.0
# UBE2W         2.0         1.0         1.0         2.0         0.0         2.0
# RDH10         2.0         1.0         1.0         2.0         0.0         2.0
# RPL7          2.0         1.0         1.0         2.0         0.0         2.0
# STAU2         2.0         1.0         1.0         2.0         0.0         2.0
#
#        SRR3018019  SRR3018024  SRR3018027  SRR3018031  ...  \
# AR            0.0         0.0         0.0         1.0  ...
# UBE2W         0.0         2.0         2.0         0.0  ...
# RDH10         0.0         2.0         2.0         0.0  ...
# RPL7          0.0         2.0         2.0         0.0  ...
# STAU2         0.0         2.0         2.0         0.0  ...
#
#        141031_UNC11-SN627_0387_AC5FAKACXX_TAGCTT_L007  \
# AR                                                0.0
# ...

# %%
df2 = df.T

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 587 entries, SRR3018011 to 140815_UNC9-SN296_0431_BC5AG8ACXX_CTTGTA_L002
# Columns: 24939 entries, AR to RN7SL91P
# dtypes: float64(24939)
# memory usage: 111.7+ MB

# %%
df2.isna()
# Out:
#                                                    AR  UBE2W  RDH10   RPL7  \
# SRR3018011                                      False  False  False  False
# SRR3018194                                      False  False  False  False
# SRR3018197                                      False  False  False  False
# SRR3018199                                      False  False  False  False
# SRR3018014                                      False  False  False  False
# ...                                               ...    ...    ...    ...
# 140821_UNC11-SN627_0376_AC5FE5ACXX_GATCAG_L007  False  False  False  False
# 140821_UNC11-SN627_0376_AC5FE5ACXX_GGCTAC_L002  False  False  False  False
# 140826_UNC9-SN296_0432_AC5CAJACXX_GTGGCC_L003   False  False  False  False
# 140826_UNC9-SN296_0432_AC5CAJACXX_CGTACG_L006   False  False  False  False
# 140815_UNC9-SN296_0431_BC5AG8ACXX_CTTGTA_L002   False  False  False  False
#
# ...

# %%
df
# Out:
#            SRR3018011  SRR3018194  SRR3018197  SRR3018199  SRR3018014  \
# AR                2.0         1.0         2.0         2.0         2.0
# UBE2W             2.0         1.0         1.0         2.0         0.0
# RDH10             2.0         1.0         1.0         2.0         0.0
# RPL7              2.0         1.0         1.0         2.0         0.0
# STAU2             2.0         1.0         1.0         2.0         0.0
# ...               ...         ...         ...         ...         ...
# PLK1S1            NaN         NaN         NaN         NaN         NaN
# RNA5SP477         NaN         NaN         NaN         NaN         NaN
# RN7SKP140         NaN         NaN         NaN         NaN         NaN
# GEMIN8            NaN         NaN         NaN         NaN         NaN
# RN7SL91P          NaN         NaN         NaN         NaN         NaN
#
#            SRR3018016  SRR3018019  SRR3018024  SRR3018027  SRR3018031  ...  \
# ...

# %%
df.shape
# Out:
# (24939, 587)

# %%
df.shape[0] - df.dropna().shape[0]
# Out:
# 7443

# %%
df.dropna().shape
# Out:
# (17496, 587)

# %%
df2 = df2.fillna(-1)

# %%
df2 = df2.astype("int")

# %%
df2.to_csv("cna_matrix_transposed.txt",index=True,header=True,sep="\t")

# %%
df2.shape
# Out:
# (587, 24939)

# %%
df2
# Out:
#                                                 AR  UBE2W  RDH10  RPL7  STAU2  \
# SRR3018011                                       2      2      2     2      2
# SRR3018194                                       1      1      1     1      1
# SRR3018197                                       2      1      1     1      1
# SRR3018199                                       2      2      2     2      2
# SRR3018014                                       2      0      0     0      0
# ...                                             ..    ...    ...   ...    ...
# 140821_UNC11-SN627_0376_AC5FE5ACXX_GATCAG_L007   0      0      0     0      0
# 140821_UNC11-SN627_0376_AC5FE5ACXX_GGCTAC_L002   0      0      0     0      0
# 140826_UNC9-SN296_0432_AC5CAJACXX_GTGGCC_L003    0      1      0     0      1
# 140826_UNC9-SN296_0432_AC5CAJACXX_CGTACG_L006   -1      2      2     2      2
# 140815_UNC9-SN296_0431_BC5AG8ACXX_CTTGTA_L002    0      1      1     1      1
#
# ...

# %%
df3 = pd.read_csv("/Users/simone/Documents/dashboard/GSETS_RES_split_object/GSETS_RES_merge.tsv",sep="\t",header=0,index_col=1)

# %%
df3.shape
# Out:
# (30733, 6)

# %%
df3.columns
# Out:
# Index(['MSigDB_C1', 'NGenes', 'Direction', 'PValue', 'FDR', 'SCORE'], dtype='object')

# %%
df3.round(4).head()
# Out:
#           MSigDB_C1 NGenes Direction                PValue  \
# chr13q14  MSigDB_C1    125      Down  2.13010490761068e-05
# chr8q24   MSigDB_C1    212        Up  0.000107271686095468
# chr17q25  MSigDB_C1    233        Up  0.000467969895136107
# chr6q13   MSigDB_C1     27      Down  0.000515884773979408
# chr4q21   MSigDB_C1     79      Down  0.000644793085744726
#
#                           FDR    SCORE
# chr13q14  0.00632641157560371  21.9884
# chr8q24     0.015929845385177  17.9779
# chr17q25   0.0324403774647721  14.8891
# chr6q13    0.0324403774647721  14.8891
# chr4q21    0.0324403774647721  14.8891

# %%
df3.tail()
# Out:
#            GROUP         SUBGROUP          DATASET       ENTRY  \
# SAMPLE_ID
# SRR8528610  CRPC      NELSON_CRPC  HUTCHINSON_2019  entry_1219
# SRR8528611  CRPC      NELSON_CRPC  HUTCHINSON_2019  entry_1220
# SRR8528612  CRPC  NELSON_CRPC_low  HUTCHINSON_2019  entry_1221
# SRR8528613  CRPC  NELSON_CRPC_low  HUTCHINSON_2019  entry_1222
# SRR8528614  CRPC  NELSON_CRPC_low  HUTCHINSON_2019  entry_1223
#
#            HAS_GENOMICS_DATA LIBRARY_PREP_TECHNIQUE PATIENT_ID  \
# SAMPLE_ID
# SRR8528610                NO                  PolyA     17-036
# SRR8528611                NO                  PolyA     17-042
# SRR8528612                NO                  PolyA     17-043
# SRR8528613                NO                  PolyA     17-043
# SRR8528614                NO                  PolyA     17-043
#
#                              LIBRARY_ID      OTHER_ID      REGION  ...  \
# SAMPLE_ID                                                          ...
# ...

# %%
df3[['NGenes']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30733 entries, chr13q14 to HALLMARK_ANGIOGENESIS
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NGenes  30733 non-null  object
# dtypes: object(1)
# memory usage: 480.2+ KB

# %%
df3[['NGenes']].dropna()
# Out:
#                                    NGenes
# chr13q14                              125
# chr8q24                               212
# chr17q25                              233
# chr6q13                                27
# chr4q21                                79
# ...                                   ...
# HALLMARK_GLYCOLYSIS                   198
# HALLMARK_UV_RESPONSE_UP               157
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE    113
# HALLMARK_HEME_METABOLISM              198
# HALLMARK_ANGIOGENESIS                  36
#
# [30733 rows x 1 columns]

# %%
# !ls
# Out:
# GSETS_RES_merge.tsv      MSigDB_C2_WIKI.tsv       MSigDB_C5_CC.tsv
# MSigDB_C1.tsv            MSigDB_C3_MIRDB.tsv      MSigDB_C5_HPO.tsv
# MSigDB_C2_BIOCARTA.tsv   MSigDB_C3_MIRLEGACY.tsv  MSigDB_C5_MF.tsv
# MSigDB_C2_CGP.tsv        MSigDB_C3_TFT_LEGACY.tsv MSigDB_C6.tsv
# MSigDB_C2_KEGG.tsv       MSigDB_C4_CGN.tsv        MSigDB_C7.tsv
# MSigDB_C2_PID.tsv        MSigDB_C4_CM.tsv         MSigDB_C8.tsv
# MSigDB_C2_REACTOME.tsv   MSigDB_C5_BP.tsv         MSigDB_H.tsv
