# %%
# !ls
# Out:
# ETL-cna_matrix.ipynb
# ETL-mRNA_vst_normalized.txt  .ipynb
# ETL-mutmatrix.txt.ipynb
# Export_fromR.R
# GSETS.RData
# GSETS_RES.RData
# GSETS_RES_split_object
# GSET_split_object
# Untitled.ipynb
# cna_matrix.txt
# cna_matrix_transposed.txt
# mRNA_vst_normalized.rar
# mRNA_vst_normalized.txt
# mRNA_vst_normalized_genesubset.rar
# mRNA_vst_normalized_genesubset.txt
# mRNA_vst_normalized_transposed.txt
# mutmatrix.txt
# mutmatrix_transposed.txt
# sample_pca_and_annotations.xlsx
# sample_pca_annotations_sheet_gene2ptime_correlations.txt
# sample_pca_annotations_sheet_gene_annotations.txt
# sample_pca_annotations_sheet_pca_and_pseudotime.txt
# sample_pca_annotations_sheet_sample_annotations.txt

# %%
import pandas as pd

# %%
df = pd.read_csv("mRNA_vst_normalized_genesubset.txt",sep="\t",header=0,index_col=0)

# %%
df.head()
# Out:
#                  SRR657809  SRR661052  SRR815280  SRR815542  SRR815845  \
# ENSG00000163017  17.515345  16.184315  13.906315  15.593223  16.217798
# ENSG00000130176  15.644745  14.342819  12.687377  14.281804  14.927068
# ENSG00000175084  17.063000  16.073497  14.796713  16.570487  17.260323
# ENSG00000145936  12.399595  11.691857   9.346811  11.166011  12.029977
# ENSG00000154330  13.306097  13.137076  11.473509  11.549875  14.717887
#
#                  SRR816818  SRR816969  SRR5125442  SRR820234  SRR1069209  ...  \
# ENSG00000163017  18.883833  16.860537   16.861128  15.700210   15.820392  ...
# ENSG00000130176  16.920229  15.314529   15.315055  14.322791   14.423526  ...
# ENSG00000175084  19.059289  16.673627   16.674164  17.330830   16.216404  ...
# ENSG00000145936  13.674392  11.912398   11.912617  11.778158   11.070876  ...
# ENSG00000154330  15.116962  13.654467   13.655112  12.990010   12.515357  ...
#
# ...

# %%
df2 = df.round(3).T

# %%
df2.head()
# Out:
#            ENSG00000163017  ENSG00000130176  ENSG00000175084  ENSG00000145936  \
# SRR657809           17.515           15.645           17.063           12.400
# SRR661052           16.184           14.343           16.073           11.692
# SRR815280           13.906           12.687           14.797            9.347
# SRR815542           15.593           14.282           16.570           11.166
# SRR815845           16.218           14.927           17.260           12.030
#
#            ENSG00000154330  ENSG00000163431  ENSG00000182253  ENSG00000128591  \
# SRR657809           13.306           14.150           15.190           14.613
# SRR661052           13.137           14.065           13.909           13.991
# SRR815280           11.474           12.717           12.368           11.899
# SRR815542           11.550           13.159           13.519           14.884
# SRR815845           14.718           15.284           14.737           15.090
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1097 entries, SRR657809 to SRR8528614
# Columns: 25004 entries, ENSG00000163017 to ENSG00000265606
# dtypes: float64(25004)
# memory usage: 209.3+ MB

# %%
df2.isna()
# Out:
#             ENSG00000163017  ENSG00000130176  ENSG00000175084  \
# SRR657809             False            False            False
# SRR661052             False            False            False
# SRR815280             False            False            False
# SRR815542             False            False            False
# SRR815845             False            False            False
# ...                     ...              ...              ...
# SRR8528610            False            False            False
# SRR8528611            False            False            False
# SRR8528612            False            False            False
# SRR8528613            False            False            False
# SRR8528614            False            False            False
#
#             ENSG00000145936  ENSG00000154330  ENSG00000163431  \
# SRR657809             False            False            False
# SRR661052             False            False            False
# ...

# %%
df2.to_csv("mRNA_vst_normalized_genesubset_transposed.txt",index=True,header=True,sep="\t")

# %%
df2.shape
# Out:
# (1097, 25004)
