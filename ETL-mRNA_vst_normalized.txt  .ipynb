# %%
# !ls
# Out:
# Export_fromR.R
# GSETS.RData
# GSETS_RES.RData
# GSETS_RES_split_object
# GSET_split_object
# Untitled.ipynb
# cna_matrix.txt
# mRNA_vst_normalized.rar
# mRNA_vst_normalized.txt
# mRNA_vst_normalized_genesubset.rar
# mRNA_vst_normalized_genesubset.txt
# mutmatrix.txt
# sample_pca_and_annotations.xlsx
# sample_pca_annotations_sheet_gene2ptime_correlations.txt
# sample_pca_annotations_sheet_gene_annotations.txt
# sample_pca_annotations_sheet_pca_and_pseudotime.txt
# sample_pca_annotations_sheet_sample_annotations.txt

# %%
import pandas as pd

# %%
df = pd.read_csv("mRNA_vst_normalized.txt",sep="\t",header=0,index_col=0)

# %%
df.round(3).head(10)
# Out:
#                  SRR657809  SRR661052  SRR815280  SRR815542  SRR815845  \
# ENSG00000223972      4.667      3.553      3.553      4.337      3.553
# ENSG00000227232      8.067      7.693      9.031      8.870      9.080
# ENSG00000278267      3.553      4.663      5.520      5.797      5.303
# ENSG00000243485      3.553      3.553      3.553      3.553      3.553
# ENSG00000284332      3.553      3.553      3.553      3.553      3.553
# ENSG00000237613      3.553      3.553      3.553      3.553      3.553
# ENSG00000268020      3.553      3.553      3.553      3.553      3.553
# ENSG00000240361      3.553      3.553      3.553      3.553      3.553
# ENSG00000186092      3.553      3.553      3.553      3.553      3.553
# ENSG00000238009      4.829      4.059      3.553      3.553      5.026
#
#                  SRR816818  SRR816969  SRR5125442  SRR820234  SRR1069209  ...  \
# ENSG00000223972      4.016      3.553       3.553      3.553       3.553  ...
# ...

# %%
df.columns
# Out:
# Index(['SRR657809', 'SRR661052', 'SRR815280', 'SRR815542', 'SRR815845',
#        'SRR816818', 'SRR816969', 'SRR5125442', 'SRR820234', 'SRR1069209',
#        ...
#        'SRR8528605', 'SRR8528606', 'SRR8528607', 'SRR8528608', 'SRR8528609',
#        'SRR8528610', 'SRR8528611', 'SRR8528612', 'SRR8528613', 'SRR8528614'],
#       dtype='object', length=1097)

# %%
df2 = df.round(3).T

# %%
df2.isna()
# Out:
#             ENSG00000223972  ENSG00000227232  ENSG00000278267  \
# SRR657809             False            False            False
# SRR661052             False            False            False
# SRR815280             False            False            False
# SRR815542             False            False            False
# SRR815845             False            False            False
# ...                     ...              ...              ...
# SRR8528610            False            False            False
# SRR8528611            False            False            False
# SRR8528612            False            False            False
# SRR8528613            False            False            False
# SRR8528614            False            False            False
#
#             ENSG00000243485  ENSG00000284332  ENSG00000237613  \
# SRR657809             False            False            False
# SRR661052             False            False            False
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1097 entries, SRR657809 to SRR8528614
# Columns: 64792 entries, ENSG00000223972 to ENSG00000277374
# dtypes: float64(64792)
# memory usage: 542.3+ MB

# %%
df2.shape
# Out:
# (1097, 64792)

# %%
df2.to_csv("mRNA_vst_normalized_transposed.txt",index=True,header=True,sep="\t")

# %%
df2['ENSG00000163017']
# Out:
# SRR657809     17.515
# SRR661052     16.184
# SRR815280     13.906
# SRR815542     15.593
# SRR815845     16.218
#                ...
# SRR8528610     7.244
# SRR8528611     5.750
# SRR8528612     8.572
# SRR8528613    10.396
# SRR8528614     4.070
# Name: ENSG00000163017, Length: 1097, dtype: float64
